# %% [markdown]
# ## 0. install and load packages

# %%
from google.colab import drive
drive.mount('/content/gdrive')#, force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install bertopic #[all]
# !pip install sentence_transformers
# !pip install umap-learn
# !pip install hdbscan

# %%
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
from umap import UMAP
from hdbscan import HDBSCAN
import numpy as np
import pandas as pd
import pickle
from bertopic import BERTopic

# %% [markdown]
# ## 1. load and combine datasets

# %%
dataset_list = ['df_v3_1_200000','df_v3_200000_400000','df_v3_400000_600000','df_v3_600000_800000','df_v3_800000_850000','df_v3_850000_905573']
dfs = [pd.read_csv('gdrive/My Drive/nlp-tm-proj/PolUSA/PolUSA-data/{}.csv'.format(dataset)) for dataset in dataset_list]
dfs = pd.concat(dfs)
dfs.reset_index(drop = True, inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905573 entries, 0 to 905572
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         905573 non-null  object
#  1   date_publish               905572 non-null  object
#  2   outlet                     905573 non-null  object
#  3   headline                   905547 non-null  object
#  4   lead                       840629 non-null  object
#  5   body                       905572 non-null  object
#  6   authors                    732635 non-null  object
#  7   domain                     905571 non-null  object
#  8   url                        905571 non-null  object
#  9   political_leaning          905571 non-null  object
#  10  headline_len               905545 non-null  float64
#  11  body_len                   905571 non-null  float64
#  12  headline_lang              905547 non-null  object
#  13  body_lang                  905572 non-null  object
#  14  if_eng_body                905573 non-null  int64
#  15  if_eng_headline            905573 non-null  int64
#  16  if_eng_headline_nonstrict  905573 non-null  int64
#  17  preprocessed_headline      905546 non-null  object
#  18  preprocessed_body          905572 non-null  object
#  19  if_meaningful_headline     905573 non-null  int64
#  20  if_meaningful_body         905573 non-null  int64
# dtypes: float64(2), int64(5), object(14)
# memory usage: 145.1+ MB

# %%
# only keep the rows with conditions: 
## 1. headline is English 2. headline is meaningful and not null
dfs = dfs[(dfs.if_eng_headline_nonstrict==1)&(dfs.if_meaningful_headline==1)&(dfs.headline==dfs.headline)]

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 890940 entries, 0 to 905572
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   id                         890940 non-null  object
#  1   date_publish               890940 non-null  object
#  2   outlet                     890940 non-null  object
#  3   headline                   890940 non-null  object
#  4   lead                       826858 non-null  object
#  5   body                       890939 non-null  object
#  6   authors                    722692 non-null  object
#  7   domain                     890939 non-null  object
#  8   url                        890939 non-null  object
#  9   political_leaning          890939 non-null  object
#  10  headline_len               890939 non-null  float64
#  11  body_len                   890939 non-null  float64
#  12  headline_lang              890940 non-null  object
#  13  body_lang                  890939 non-null  object
#  14  if_eng_body                890940 non-null  int64
#  15  if_eng_headline            890940 non-null  int64
#  16  if_eng_headline_nonstrict  890940 non-null  int64
#  17  preprocessed_headline      890940 non-null  object
#  18  preprocessed_body          890939 non-null  object
#  19  if_meaningful_headline     890940 non-null  int64
#  20  if_meaningful_body         890940 non-null  int64
# dtypes: float64(2), int64(5), object(14)
# memory usage: 149.5+ MB

# %%
# all rows are unique
len(dfs.drop_duplicates())
# Out:
# 890940

# %%
### use only first 10000 rows for testing ###
dfs = dfs[0:10000]

# %% [markdown]
# ## 2. Fit BerTopic model for headlines
#
# - prepare custom embedding, umap, hdbscan and vectorizor models with the paramters below
# - use Bertopic to wrap them
# - fit a Topic model

# %%
# Prepare custom models
embedding_model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
umap_model = UMAP(n_neighbors=15, n_components=10, min_dist=0.0, metric='cosine')
hdbscan_model = HDBSCAN(min_cluster_size=10, metric='euclidean', cluster_selection_method='eom', prediction_data=True)
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=244715968.0), HTML(value='')))

# %%
# Pass the custom models to BERTopic
topic_model = BERTopic(embedding_model = embedding_model,
                       umap_model=umap_model, 
                       hdbscan_model=hdbscan_model, 
                       vectorizer_model=vectorizer_model,
                       calculate_probabilities = False, #Whether to calculate the topic probabilities. This could slow down the extraction of topics if you have many documents (> 100_000).
                       verbose = False, #Changes the verbosity of the model, Set to True if you want to track the stages of the model.
                       nr_topics = None) #If this is set to None, no reduction is applied. Use "auto" to automatically reduce topics that have a similarity of at least 0.9, do not maps all others.

# %%
#topics, probabilities = topic_model.fit_transform(headlines[0:10000], embeddings[0:10000])
topics, probabilities = topic_model.fit_transform(dfs.headline.tolist())

# %% [markdown]
# ## 3. Save and load the default TM model for headline
#
# The default model for headline:
# - using embeddings by Sbert: distilbert-base-nli-stsb-mean-tokens
# - using the parameters above for umap, sdbscan and CV

# %%
### save the default model
topic_model.save("default_model_headline", save_embedding_model=True)
# !cp -r default_model_headline "gdrive/My Drive/nlp-tm-proj/PolUSA/saved-models-and-embeddings/"

# %%
### load the default model
topic_model = BERTopic.load("gdrive/My Drive/nlp-tm-proj/PolUSA/saved-models-and-embeddings/default_model_headline") #load saved model

# %% [markdown]
# ## 4. Visualize the default model

# %%
topic_freq = topic_model.get_topic_freq()
outliers = topic_freq['Count'][topic_freq['Topic']==-1].iloc[0]
print(f"{outliers} documents have not been classified")
print(f"The other {topic_freq['Count'].sum() - outliers} documents are {topic_freq['Topic'].shape[0]-1} topics")
# Out:
# 4264 documents have not been classified
# The other 5736 documents are 182 topics

# %% [markdown]
# ### 4.1 Get topics and the number of docs within each topic

# %%
topic_freq[:10]
# Out:
#    Topic  Count
# 0     -1   4264
# 1    136    203
# 2    125    186
# 3    138    149
# 4    179    141
# 5    129    137
# 6      2    131
# 7     77    120
# 8    141    108
# 9    172     96

# %%
print(f"There are {topic_freq['Count'].iloc[1]} documents that are talking about topic ID {topic_freq['Topic'].iloc[1]}")
# Out:
# There are 203 documents that are talking about topic ID 136

# %% [markdown]
# ### 4.2 Get keywords and their c-TF-IDF scores for a certain topic
#
# - Return top n words for a specific topic and their c-TF-IDF scores

# %%
# keywords and their probs in Topic ID 127
topic_model.get_topic(topic_freq['Topic'].iloc[1])
# Out:
# [('brexit', 0.056884530441472535),
#  ('uk', 0.031217653400060358),
#  ('eu', 0.02845105942897282),
#  ('ivan rogers', 0.017181544677012762),
#  ('britain', 0.014501503323523691),
#  ('northern ireland', 0.010997578293958976),
#  ('hard brexit', 0.01071434873380965),
#  ('ambassador eu', 0.010019450828152438),
#  ('eu envoy', 0.008662702021503344),
#  ('england', 0.008590772338506381)]

# %% [markdown]
# ### 4.3 Get information about each topic including its id, frequency, and name

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name
# 0       -1   4264                -1_house_russia_donald trump_donald
# 1      136    203                       136_brexit_uk_eu_ivan rogers
# 2      125    186                125_mln brief_pct stake_sell_shares
# 3      138    149  138_repeal_obamacare repeal_repeal obamacare_r...
# 4      179    141   179_hacking_russian hacking_russia hacking_hacks
# ..     ...    ...                                                ...
# 170    124     11  124_overhaul_considers overhaul_strategy remod...
# 169     51     11  51_president farewell_emotional president_fare...
# 168    147     11  147_unemployment_wage_inequality primary_worki...
# 181    117     10  117_fear safety_officers fear_safety pew_reluc...
# 182     68     10  68_wells fargo_wells_overhauls pay_fargo overh...
#
# [183 rows x 3 columns]

# %% [markdown]
# ### 4.4 Find topics most similar to a search_term
#
# - Creates an embedding for search_term and compares that with the topic embeddings. The most similar topics are returned along with their similarity values.
#
# - The search_term can be of any size but since it compares with the topic representation it is advised to keep it below 5 words.
#
# - This method can only be used if you did not use custom embeddings.

# %%
topic_model.find_topics("brexit", top_n=5)
# Out:
# ([127, 126, 96, 64, 18],
#  [0.7487480013966736,
#   0.48288976267228834,
#   0.41055808881343714,
#   0.40183953772843384,
#   0.39185822375897406])

# %% [markdown]
# ### 4.5 Visualize topics

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="652685a7-db26-4870-b23e-0a024b424da8" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("652685a7-db26-4870-b23e-0a024b424da8")) {                    Plotly.newPlot(                        "652685a7-db26-4870-b23e-0a024b424da8",                        [{"customdata": [[-6.712776184082031, 5.687359809875488, 0, "npr | way npr | npr way | soda npr | goats soda", 22], [5.444424152374268, 1.353087067604065, 1, "warning shots | shots iranian | fires warning | iranian | iranian vessels", 14], [9.84257698059082, 13.248299598693848, 2, "germany | german | nazi | german police | nazi germany", 131], [12.479575157165527, -0.08907497674226761, 3, "iranian | iranian leader | rafsanjani dead | iranian president | rafsanjani iran", 32], [-2.2077932357788086, 2.027083396911621, 4, "philippines | russian warships | warships philippines | philippines exercises | manila", 13], [13.950970649719238, 7.043848991394043, 5, "australia | indonesia | assault australia | australia shares | australian", 32], [17.073991775512695, 16.464351654052734, 6, "tuition | free tuition | free | york governor | proposes free", 19], [21.905445098876953, 10.844243049621582, 7, "brazil | brazil prison | portugal | riot brazil | brazilian", 79], [7.8835248947143555, 14.022951126098633, 8, "france | le pen | pen | french presidential | french farmer", 66], [7.33976936340332, 1.2865763902664185, 9, "italy | italian | italy star | hacking draghi | italy arrests", 35], [13.352705955505371, -0.990044355392456, 10, "official mexico | mexico | shot mexico | officer mexico | shooting consular", 27], [5.801276206970215, -4.900381565093994, 11, "megyn kelly | kelly | verizon | yahoo | kelly leaving", 26], [21.919816970825195, 10.190990447998047, 12, "spacex | space | faa | laser pointed | rocket", 46], [10.29538631439209, 13.830556869506836, 13, "price hike | mexicans | gasoline price | mexico gasoline | mexico gas", 28], [0.4109868109226227, 8.495230674743652, 14, "norway | norwegian | denmark | norwegian mass | breivik", 29], [0.40591201186180115, 8.492284774780273, 15, "volkswagen | emissions scandal | emissions cheating | cheating | self driving", 76], [9.943942070007324, -6.321358680725098, 16, "missile | icbm | test launch | missile test | jong", 36], [9.935373306274414, -6.33176326751709, 17, "korea | samsung | samsung heir | heir | south korea", 31], [11.80471134185791, 6.467014789581299, 18, "20 | 20m | week abortion | 20 week | abortion ban", 16], [-5.839472770690918, 10.846597671508789, 19, "kerry | kerry apologizes | apologizes past | apologizes state | gays kerry", 15], [-2.0610830783843994, 6.7468743324279785, 20, "jay clayton | jay | street lawyer | lawyer | lawyer jay", 14], [7.466279983520508, 1.4115179777145386, 21, "syria russia | starts withdraw | drawdown aircraft | withdraw forces | syrian drawdown", 23], [6.618529319763184, 10.504975318908691, 22, "mexico pay | wall trump | pay border | mexico border | mexico wall", 32], [7.822451591491699, 14.08332347869873, 23, "laden | bin laden | laden son | son | osama", 16], [2.956165313720703, 13.522457122802734, 24, "mexico | mexican | mexico plant | plant mexico | mexican ford", 48], [2.993436813354492, 13.559219360351562, 25, "toyota | mexico plant | mexico | toyota stock | mexico trump", 18], [9.726097106933594, -6.527076721191406, 26, "roof | dylann | dylann roof | church | charleston", 88], [5.309823036193848, 1.2012476921081543, 27, "corrections | corrections amplifications | amplifications corrections | treatment corrections | amplifications gene", 13], [-2.143433094024658, 6.829685688018799, 28, "dan coats | intelligence trump | coats intelligence | coats director | sen coats", 22], [5.638861656188965, 1.596029281616 ...

# %%
# need to set: calculate_probabilities = True for visualize_distribution
topic_model.visualize_distribution(probabilities[0])

# %% [markdown]
# ## 5. Update dataset:
#
# - Add columns obtained from topic_model to dfs
# - columns added: 'topic_id', 'top_10_keywords_with_score', 'top_10_keywords', 'Topic','Count', 'Name'

# %%
topics, probabilities = topic_model.fit_transform(dfs.headline.tolist())

# %%
dfs['topic_id'] = topics
dfs['top_10_keywords_with_score'] = dfs.apply(lambda x: topic_model.get_topic(x.topic_id), axis = 1)

# %%
# extract all keywords from kw_score_column and tranfer them to an added column kw_column. Then, update the dataframe. 
def extract_keywords(df, kw_score_column, kw_column):
    df[kw_column] =''
    for i in df.index.tolist():
        df[kw_column][i] = [items[0] for items in df[kw_score_column][i]]
    return df

# %%
dfs = extract_keywords(dfs, 'top_10_keywords_with_score', 'top_10_keywords')
dfs = pd.merge(dfs,topic_model.get_topic_info(), left_on=['topic_id'], right_on=['Topic'], how ='left')

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          10000 non-null  object
#  1   date_publish                10000 non-null  object
#  2   outlet                      10000 non-null  object
#  3   headline                    10000 non-null  object
#  4   lead                        9032 non-null   object
#  5   body                        10000 non-null  object
#  6   authors                     8674 non-null   object
#  7   domain                      10000 non-null  object
#  8   url                         10000 non-null  object
#  9   political_leaning           10000 non-null  object
#  10  headline_len                10000 non-null  float64
#  11  body_len                    10000 non-null  float64
#  12  headline_lang               10000 non-null  object
#  13  body_lang                   10000 non-null  object
#  14  if_eng_body                 10000 non-null  int64
#  15  if_eng_headline             10000 non-null  int64
#  16  if_eng_headline_nonstrict   10000 non-null  int64
#  17  preprocessed_headline       10000 non-null  object
#  18  preprocessed_body           10000 non-null  object
#  19  if_meaningful_headline      10000 non-null  int64
#  20  if_meaningful_body          10000 non-null  int64
#  21  topic_id                    10000 non-null  int64
#  22  top_10_keywords_with_score  10000 non-null  object
#  23  top_10_keywords             10000 non-null  object
#  24  Topic                       10000 non-null  int64
#  25  Count                       10000 non-null  int64
#  26  Name                        10000 non-null  object
# dtypes: float64(2), int64(8), object(17)
# memory usage: 2.1+ MB

# %%
dfs.sample(3)
# Out:
#             id  ...                                              Name
# 6723   3972022  ...               -1_donald trump_donald_russia_obama
# 9320  38929560  ...                      127_brexit_uk_eu_ivan rogers
# 8636  59612426  ...  163_hacking_russian hacking_russia hacking_hacks
#
# [3 rows x 27 columns]

# %% [markdown]
# ## 6. Update default model: reduce the number of topics to 30

# %%
new_topics, new_probs = topic_model.reduce_topics(dfs.headline.tolist(), topics, probabilities, nr_topics=30)

# %%
topic_model.get_topic_info()[:10]
# Out:
#    Topic  Count                                               Name
# 0     -1   6109                 -1_trump_donald_donald trump_obama
# 1    164    271   164_hacking_russian hacking_trump_russia hacking
# 2    114    205  114_facebook_facebook live_hate crime_torture ...
# 3    124    199                     124_china_taiwan_chinese_apple
# 4    131    196  131_repeal_obamacare repeal_replace_repeal oba...
# 5    112    187           112_orlando_killed_mexico_orlando police
# 6     56    184  56_nightclub_istanbul_istanbul nightclub_night...
# 7    123    179            123_mln brief_holdings_pct stake_shares
# 8     85    177  85_farewell_farewell address_obama farewell_fa...
# 9    117    158                       117_brexit_uk_eu_ivan rogers

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="f60a154c-927e-491d-a9e9-1898155d0721" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f60a154c-927e-491d-a9e9-1898155d0721")) {                    Plotly.newPlot(                        "f60a154c-927e-491d-a9e9-1898155d0721",                        [{"customdata": [[-0.8598217964172363, 5.659588813781738, 2, "germany | german | berlin | nazi | german police", 131], [-8.256011009216309, 1.8252352476119995, 4, "brazil | brazil prison | portugal | brazilian | riot brazil", 80], [-8.895645141601562, 1.326826572418213, 6, "roof | dylann roof | dylann | church | church shooter", 81], [-2.016589879989624, 7.112948417663574, 18, "mexico | border wall | mexico pay | mexican | mexicans", 91], [-1.8953205347061157, 6.926325798034668, 19, "mexico | mexico plant | mexican | ford cancels | ford plant", 74], [-10.102959632873535, 10.223852157592773, 51, "israeli police | benjamin netanyahu | jerusalem truck | netanyahu questioned | question netanyahu", 91], [-1.484984278678894, 5.473144054412842, 54, "oil | gas | oil prices | coal | stocks gulf", 85], [-10.034158706665039, 10.32571029663086, 56, "nightclub | istanbul | istanbul nightclub | nightclub attack | turkish", 184], [-9.015592575073242, 1.555345892906189, 57, "chicago | chicago police | homicides | oakland police | policing", 114], [-8.584672927856445, 1.810486078262329, 59, "marines | billion | bahrain | 300 | affiliates billion", 122], [-9.920098304748535, 10.426979064941406, 63, "syria | baghdad | iraqi | syrian | bomb", 133], [8.892017364501953, 15.177308082580566, 72, "tillerson | rex tillerson | exxon | confirmation hearing | tillerson confirmation", 120], [-3.099829912185669, 5.677793025970459, 85, "farewell | farewell address | obama farewell | farewell speech | goodbye", 177], [-9.391193389892578, 0.37961670756340027, 98, "philippines | bin laden | laden | laden son | philippine", 119], [-9.147329330444336, 0.8768332004547119, 102, "lauderdale | airport shooting | fort lauderdale | lauderdale airport | shooting suspect", 106], [-9.324485778808594, 0.48574748635292053, 112, "orlando | killed | mexico | orlando police | dead", 187], [-9.243815422058105, 1.7063984870910645, 114, "facebook | facebook live | hate crime | torture video | hate crimes", 205], [-0.7170364856719971, 5.8792643547058105, 117, "brexit | uk | eu | ivan rogers | britain", 158], [-2.0348165035247803, 6.268814563751221, 123, "mln brief | holdings | pct stake | shares | agreement brief", 179], [-1.8800914287567139, 5.534668445587158, 124, "china | taiwan | chinese | apple | taiwan president", 199], [2.702857494354248, 11.22331428527832, 131, "repeal | obamacare repeal | replace | repeal obamacare | repeal replace", 196], [-1.859087586402893, 6.430547714233398, 132, "december | fiat | 000 jobs | fiat chrysler | jobs december", 78], [2.9937069416046143, 11.311738014221191, 134, "house republicans | congressional ethics | house gop | ethics office | ethics watchdog", 80], [2.7369234561920166, 11.13211441040039, 136, "painting | obamacare | pigs | care | painting capitol", 91], [9.088363647460938, 15.373817443847656, 137, "jeff sessions | jeff | confirmation hearing | booker | sessions attorney", 151], [-0.9487645030021667, 5.766859531402588, 138, "2017 | 2017 hold | strong 2017 | 2017 2017 | 2017 stocks", 96], [-1.651720404624939, 5.847283840179443, 142, "wall street | stocks | jay clayton | jay | street lawyer", 110], [-2.5716426372528076, 5.435175895690918, 151, "business | trump | business interests | trump business | blasts trump", 87], [-2.862468719482422, 5.486942768096924, 158, "donald trump | donald | trump | trump trump | trump press", 95], [8.602694511413574, 14.888072967529297, 164, "hacking | russian hackin ...
